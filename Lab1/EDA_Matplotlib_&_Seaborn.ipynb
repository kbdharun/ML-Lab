# %%
import pandas as pd
import numpy as np
# matplotlib - package for basic data viz plot : bar,scatter,line,pie,hist plots
import matplotlib.pyplot as plt
# seaborn package used for descriptive visulaization - KDE(density),boxplot,violin,heatmap plots
import seaborn as sns

# %%
auto_price = pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Automobile_price_data__Raw_.csv")
auto_price.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto_price.drop(['symboling','normalized-losses'],axis = 1, inplace = True)

# %%
# replace all columns '?' by np.nan
auto_df = auto_price.replace('?', np.nan)

# %%
auto_df.dropna(inplace = True)

# %%
cols = ['bore','stroke','horsepower','peak-rpm','price']
# method to change columns to numeric data types
auto_df[cols] = auto_df[cols].apply(pd.to_numeric)

# %% [markdown]
# ##### Line Plot
#     * Univariate & Bivariate (Replationship Plots)
#     * Time Series Analysis - Univariate Plots

# %%
auto_df['price'].sort_values().unique()
# Out:
# array([ 5118,  5151,  5195,  5348,  5389,  5399,  5499,  5572,  6095,
#         6189,  6229,  6295,  6338,  6377,  6479,  6488,  6529,  6575,
#         6649,  6669,  6692,  6695,  6785,  6795,  6849,  6855,  6918,
#         6938,  6989,  7053,  7099,  7126,  7129,  7198,  7295,  7299,
#         7349,  7395,  7463,  7499,  7603,  7609,  7689,  7738,  7775,
#         7788,  7799,  7895,  7898,  7957,  7975,  7995,  7999,  8013,
#         8058,  8189,  8195,  8238,  8249,  8358,  8449,  8495,  8499,
#         8778,  8845,  8921,  8948,  8949,  9095,  9233,  9258,  9279,
#         9298,  9495,  9538,  9549,  9639,  9959,  9960,  9980,  9988,
#         9989,  9995, 10198, 10245, 10295, 10345, 10595, 10698, 10898,
#        11048, 11199, 11245, 11248, 11259, 11549, 11595, 11694, 11850,
#        11900, 12170, 12290, 12440, 12629, 12764, 12940, 12945, 12964,
#        13200, 13295, 13415, 13495, 13499, 13845, 13860, 13950, 14399,
# ...

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize = (10,7))
plt.plot(auto_df['price'].sort_values().unique())
plt.show()
# Out:
# <ipython-input-8-8a3ccb1d3291>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
auto_df.sort_values('price')
# Out:
#               make fuel-type aspiration num-of-doors   body-style  \
# 138         subaru       gas        std          two    hatchback
# 18       chevrolet       gas        std          two    hatchback
# 50           mazda       gas        std          two    hatchback
# 150         toyota       gas        std          two    hatchback
# 76      mitsubishi       gas        std          two    hatchback
# ..             ...       ...        ...          ...          ...
# 17             bmw       gas        std         four        sedan
# 128        porsche       gas        std          two  convertible
# 73   mercedes-benz       gas        std         four        sedan
# 16             bmw       gas        std          two        sedan
# 74   mercedes-benz       gas        std          two      hardtop
#
#     drive-wheels engine-location  wheel-base  length  width  ...  engine-size  \
# 138          fwd           front        93.7   156.9   63.4  ...           97
# ...

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize = (9,6))
plt.plot(auto_df.sort_values('price')['price'],
         auto_df.sort_values('price')['city-mpg'], color = 'b')
plt.title('Bivariate Line Plot - Price vs Mileage', size = 12)
plt.xlabel('Price')
plt.ylabel('Mileage')
plt.show()
# Out:
# <ipython-input-10-3315fa15a764>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ##### Bar Plot
#     * Bivariate / Univariate  Analysis
#     * Bar Chart used by Categorical, Nominal Data
#     * Use Bar Plot for limited categocal responses.

# %%
auto_df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# mazda            12
# volvo            11
# peugot           11
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: make, dtype: int64

# %%
plt.figure(figsize = (9,6))
plt.bar(x = auto_df['make'].value_counts().index,
        height = auto_df['make'].value_counts().values)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Histogram
#     * Continious Data - Study spread / distribution of continious data.
#     * Univariate Analysis.

# %%
plt.figure(figsize = (10,6))
# bins = num of intervals
plt.hist(auto_df['price'], bins = 15)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram Plot - Vehicle Price')
plt.show()

# %% [markdown]
# ##### Scatter PLot
#     * Scatter Plots is plotted between numerical values.
#     * It shows relationship plots b/w x & y.
#     * Bivariate Analysis

# %%
plt.figure(figsize = (7,5))
# marker = 's','*','^','>','<','o','.','d'
sns.scatterplot(x = auto_df['city-mpg'], y = auto_df['price'], color = 'deeppink',
                marker = 's', alpha = 0.6)
plt.show()

# %%
plt.figure(figsize = (7,5))
# marker = 's','*','^','>','<','o','.','d'
# alpha = opacity of color
sns.scatterplot(x = auto_df['horsepower'], y = auto_df['price'], color = 'b',
                marker = 'o', alpha = 0.6)
plt.show()

# %% [markdown]
# ###### Pie
#     * Univariate Distribution Analysis.

# %%
plt.style.use('ggplot')
plt.figure(figsize = (6,6))
plt.pie(auto_df['make'].value_counts(), autopct = '%0.0f%%',
        labels = auto_df['make'].value_counts().index)
plt.show()

# %% [markdown]
# ##### Kernel Density Estimator (KDE)
#     * Distribution Plot : Histogram + Density Plot
#     * Probability Density Function (PDF)

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(auto_df['engine-size'], bins = 20, color = 'b')
plt.show()
# Out:
# <Axes: xlabel='engine-size', ylabel='Density'>

# %%
plt.style.use('seaborn-whitegrid')
sns.distplot(auto_df['engine-size'], bins = 20, color = 'b', hist = False)
plt.show()

# %% [markdown]
# ###### Correlation
#     * Correlation represents linear relationship between two variables.
#     * corr() range from -1 to +1, corr b/w two variables = +ve, both are directly proportional
#     * corr b/w two variables = -ve, both are inversly proportional
#     * corr b/w two variables = 0 or closer to zero, there is no relationalship b/w variables.

# %%
# correlation shows linear relationship b/w variables,
auto_df.corr()
# Out:
#                    wheel-base    length     width    height  curb-weight  \
# wheel-base           1.000000  0.879307  0.818465  0.591239     0.782173
# length               0.879307  1.000000  0.857368  0.491050     0.882694
# width                0.818465  0.857368  1.000000  0.310640     0.867640
# height               0.591239  0.491050  0.310640  1.000000     0.305837
# curb-weight          0.782173  0.882694  0.867640  0.305837     1.000000
# engine-size          0.568375  0.686998  0.739903  0.026906     0.857188
# bore                 0.495957  0.606373  0.541633  0.182445     0.645070
# stroke               0.174225  0.121888  0.188733 -0.054338     0.175349
# compression-ratio    0.252234  0.156061  0.188631  0.253934     0.161030
# horsepower           0.377040  0.589650  0.621532 -0.081730     0.762154
# peak-rpm            -0.350823 -0.276144 -0.247612 -0.257334    -0.278528
# city-mpg            -0.504499 -0.702143 -0.657153 -0.111166    -0.777763
# ...

# %%
plt.figure(figsize = (10,8))
sns.heatmap(auto_df.corr(), annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (3,7))
sns.heatmap(auto_df.corr()[['price']], annot = True)
# Out:
# <Axes: >

# %%
sns.countplot(x = 'body-style', data = auto_df)
# Out:
# <Axes: xlabel='body-style', ylabel='count'>

# %%
plt.figure(figsize = (8, 3))
sns.boxplot(auto_df['price'], orient = 'h')
# Out:
# <Axes: >
